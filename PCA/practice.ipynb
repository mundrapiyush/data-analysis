# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/ratings.csv')
pca = PCA(random_state=42)
pca_df = pca.fit(df)
pca_df.components_
pca_df.explained_variance_ratio_
var_cumulative = np.cumsum(pca_df.explained_variance_ratio_)
plt.plot(range(1, len(var_cumulative) + 1), var_cumulative)
